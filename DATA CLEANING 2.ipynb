# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Bapela Kanyane\Downloads\layoffs.csv")
df
# Out:
#                company       location     industry  total_laid_off  \
# 0            Atlassian         Sydney        Other           500.0
# 1             SiriusXM  New York City        Media           475.0
# 2               Alerzo         Ibadan       Retail           400.0
# 3               UpGrad         Mumbai    Education           120.0
# 4                 Loft      Sao Paulo  Real Estate           340.0
# ...                ...            ...          ...             ...
# 2356         Blackbaud     Charleston        Other           500.0
# 2357             Yahoo    SF Bay Area     Consumer          1600.0
# 2358             Hibob       Tel Aviv           HR            70.0
# 2359            Casper  New York City       Retail             NaN
# 2360  Wildlife Studios      Sao Paulo     Consumer           300.0
#
#       percentage_laid_off        date     stage        country  \
# 0                    0.05    3/6/2023  Post-IPO      Australia
# 1                    0.08    3/6/2023  Post-IPO  United States
# 2                     NaN    3/6/2023  Series B        Nigeria
# 3                     NaN    3/6/2023   Unknown          India
# 4                    0.15    3/3/2023   Unknown         Brazil
# ...                   ...         ...       ...            ...
# 2356                 0.14         NaN  Post-IPO  United States
# 2357                 0.20    2/9/2023  Acquired  United States
# 2358                 0.30   3/30/2020  Series A         Israel
# 2359                  NaN   9/14/2021  Post-IPO  United States
# 2360                 0.20  11/28/2022   Unknown         Brazil
#
#       funds_raised_millions
# 0                     210.0
# 1                     525.0
# 2                      16.0
# 3                     631.0
# 4                     788.0
# ...                     ...
# 2356                    NaN
# 2357                    6.0
# 2358                   45.0
# 2359                  339.0
# 2360                  260.0
#
# [2361 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2361 entries, 0 to 2360
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   company                2361 non-null   object
#  1   location               2361 non-null   object
#  2   industry               2357 non-null   object
#  3   total_laid_off         1621 non-null   float64
#  4   percentage_laid_off    1576 non-null   float64
#  5   date                   2360 non-null   object
#  6   stage                  2355 non-null   object
#  7   country                2361 non-null   object
#  8   funds_raised_millions  2152 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 166.1+ KB

# %%
df.duplicated().sum()
# Out:
# 5

# %%
df = df.drop_duplicates()
df
# Out:
#             company        location        industry  total_laid_off  \
# 0         Atlassian          Sydney           Other           500.0
# 1          SiriusXM   New York City           Media           475.0
# 2            Alerzo          Ibadan          Retail           400.0
# 3            UpGrad          Mumbai       Education           120.0
# 4              Loft       Sao Paulo     Real Estate           340.0
# ...             ...             ...             ...             ...
# 2352   HopSkipDrive     Los Angeles  Transportation             8.0
# 2353    Panda Squad     SF Bay Area        Consumer             6.0
# 2354  Tamara Mellon     Los Angeles          Retail            20.0
# 2355       EasyPost  Salt Lake City       Logistics            75.0
# 2356      Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off       date     stage        country  \
# 0                    0.05   3/6/2023  Post-IPO      Australia
# 1                    0.08   3/6/2023  Post-IPO  United States
# 2                     NaN   3/6/2023  Series B        Nigeria
# 3                     NaN   3/6/2023   Unknown          India
# 4                    0.15   3/3/2023   Unknown         Brazil
# ...                   ...        ...       ...            ...
# 2352                 0.10  3/13/2020   Unknown  United States
# 2353                 0.75  3/13/2020      Seed  United States
# 2354                 0.40  3/12/2020  Series C  United States
# 2355                  NaN  3/11/2020  Series A  United States
# 2356                 0.14        NaN  Post-IPO  United States
#
#       funds_raised_millions
# 0                     210.0
# 1                     525.0
# 2                      16.0
# 3                     631.0
# 4                     788.0
# ...                     ...
# 2352                   45.0
# 2353                    1.0
# 2354                   90.0
# 2355                   12.0
# 2356                    NaN
#
# [2356 rows x 9 columns]

# %%
df.company.unique()
# Out:
# array(['Atlassian', 'SiriusXM', 'Alerzo', ..., 'Panda Squad',
#        'Tamara Mellon', 'Blackbaud'], dtype=object)

# %%
df.industry.unique()
# Out:
# array(['Other', 'Media', 'Retail', 'Education', 'Real Estate',
#        'Transportation', 'Marketing', nan, 'Healthcare', 'Security',
#        'Food', 'Fitness', 'Consumer', 'Logistics', 'HR', 'Support',
#        'Travel', 'Crypto', 'Finance', 'Data', 'Sales', 'Infrastructure',
#        'Hardware', 'Product', 'Construction', 'Legal', 'Energy',
#        'Manufacturing', 'Recruiting', 'Aerospace', 'Crypto Currency',
#        'Fin-Tech', 'CryptoCurrency'], dtype=object)

# %%
df["industry"]=df["industry"].str.replace("Crypto Currency","Crypto")
df["industry"]=df["industry"].str.replace("CryptoCurrency","Crypto")
# Out:
# C:\Users\Bapela Kanyane\AppData\Local\Temp\ipykernel_11888\1669300884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["industry"]=df["industry"].str.replace("Crypto Currency","Crypto")
# C:\Users\Bapela Kanyane\AppData\Local\Temp\ipykernel_11888\1669300884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["industry"]=df["industry"].str.replace("CryptoCurrency","Crypto")

# %%
df.industry.unique()
# Out:
# array(['Other', 'Media', 'Retail', 'Education', 'Real Estate',
#        'Transportation', 'Marketing', nan, 'Healthcare', 'Security',
#        'Food', 'Fitness', 'Consumer', 'Logistics', 'HR', 'Support',
#        'Travel', 'Crypto', 'Finance', 'Data', 'Sales', 'Infrastructure',
#        'Hardware', 'Product', 'Construction', 'Legal', 'Energy',
#        'Manufacturing', 'Recruiting', 'Aerospace', 'Fin-Tech'],
#       dtype=object)

# %%
df.stage.unique()
# Out:
# array(['Post-IPO', 'Series B', 'Unknown', 'Acquired', 'Series F',
#        'Series E', 'Series A', 'Subsidiary', 'Series C', 'Series G',
#        'Series D', 'Seed', 'Series H', 'Private Equity', 'Series J', nan,
#        'Series I'], dtype=object)

# %%
df.country.unique()
# Out:
# array(['Australia', 'United States', 'Nigeria', 'India', 'Brazil',
#        'United States.', 'France', 'Germany', 'Israel', 'Sweden',
#        'United Kingdom', 'Japan', 'South Korea', 'China', 'Italy',
#        'Singapore', 'Indonesia', 'Estonia', 'Canada', 'Ireland',
#        'Finland', 'Netherlands', 'Spain', 'Portugal', 'Chile', 'Colombia',
#        'Argentina', 'Seychelles', 'Austria', 'Mexico', 'Switzerland',
#        'Egypt', 'Kenya', 'Luxembourg', 'Greece', 'Poland', 'Norway',
#        'Belgium', 'Denmark', 'Hong Kong', 'New Zealand', 'Malaysia',
#        'Hungary', 'Vietnam', 'Thailand', 'Lithuania', 'Ghana', 'Senegal',
#        'Pakistan', 'United Arab Emirates', 'Peru', 'Bahrain', 'Romania',
#        'Turkey', 'Russia', 'Uruguay', 'Bulgaria', 'South Africa',
#        'Czech Republic', 'Myanmar'], dtype=object)

# %%
df["country"]=df["country"].str.replace("United States.","United States")
df
# Out:
# C:\Users\Bapela Kanyane\AppData\Local\Temp\ipykernel_11888\587770639.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["country"]=df["country"].str.replace("United States.","United States")
# C:\Users\Bapela Kanyane\AppData\Local\Temp\ipykernel_11888\587770639.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["country"]=df["country"].str.replace("United States.","United States")
#             company        location        industry  total_laid_off  \
# 0         Atlassian          Sydney           Other           500.0
# 1          SiriusXM   New York City           Media           475.0
# 2            Alerzo          Ibadan          Retail           400.0
# 3            UpGrad          Mumbai       Education           120.0
# 4              Loft       Sao Paulo     Real Estate           340.0
# ...             ...             ...             ...             ...
# 2352   HopSkipDrive     Los Angeles  Transportation             8.0
# 2353    Panda Squad     SF Bay Area        Consumer             6.0
# 2354  Tamara Mellon     Los Angeles          Retail            20.0
# 2355       EasyPost  Salt Lake City       Logistics            75.0
# 2356      Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off       date     stage        country  \
# 0                    0.05   3/6/2023  Post-IPO      Australia
# 1                    0.08   3/6/2023  Post-IPO  United States
# 2                     NaN   3/6/2023  Series B        Nigeria
# 3                     NaN   3/6/2023   Unknown          India
# 4                    0.15   3/3/2023   Unknown         Brazil
# ...                   ...        ...       ...            ...
# 2352                 0.10  3/13/2020   Unknown  United States
# 2353                 0.75  3/13/2020      Seed  United States
# 2354                 0.40  3/12/2020  Series C  United States
# 2355                  NaN  3/11/2020  Series A  United States
# 2356                 0.14        NaN  Post-IPO  United States
#
#       funds_raised_millions
# 0                     210.0
# 1                     525.0
# 2                      16.0
# 3                     631.0
# 4                     788.0
# ...                     ...
# 2352                   45.0
# 2353                    1.0
# 2354                   90.0
# 2355                   12.0
# 2356                    NaN
#
# [2356 rows x 9 columns]

# %%
df.country.unique()
# Out:
# array(['Australia', 'United States', 'Nigeria', 'India', 'Brazil',
#        'France', 'Germany', 'Israel', 'Sweden', 'United Kingdom', 'Japan',
#        'South Korea', 'China', 'Italy', 'Singapore', 'Indonesia',
#        'Estonia', 'Canada', 'Ireland', 'Finland', 'Netherlands', 'Spain',
#        'Portugal', 'Chile', 'Colombia', 'Argentina', 'Seychelles',
#        'Austria', 'Mexico', 'Switzerland', 'Egypt', 'Kenya', 'Luxembourg',
#        'Greece', 'Poland', 'Norway', 'Belgium', 'Denmark', 'Hong Kong',
#        'New Zealand', 'Malaysia', 'Hungary', 'Vietnam', 'Thailand',
#        'Lithuania', 'Ghana', 'Senegal', 'Pakistan',
#        'United Arab Emirates', 'Peru', 'Bahrain', 'Romania', 'Turkey',
#        'Russia', 'Uruguay', 'Bulgaria', 'South Africa', 'Czech Republic',
#        'Myanmar'], dtype=object)

# %%
df.dtypes
# Out:
# company                   object
# location                  object
# industry                  object
# total_laid_off           float64
# percentage_laid_off      float64
# date                      object
# stage                     object
# country                   object
# funds_raised_millions    float64
# dtype: object

# %%
df["date"] = pd.to_datetime(df["date"])
# Out:
# C:\Users\Bapela Kanyane\AppData\Local\Temp\ipykernel_11888\3228555721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["date"] = pd.to_datetime(df["date"])

# %%
df.dtypes
# Out:
# company                          object
# location                         object
# industry                         object
# total_laid_off                  float64
# percentage_laid_off             float64
# date                     datetime64[ns]
# stage                            object
# country                          object
# funds_raised_millions           float64
# dtype: object

# %%
df
# Out:
#             company        location        industry  total_laid_off  \
# 0         Atlassian          Sydney           Other           500.0
# 1          SiriusXM   New York City           Media           475.0
# 2            Alerzo          Ibadan          Retail           400.0
# 3            UpGrad          Mumbai       Education           120.0
# 4              Loft       Sao Paulo     Real Estate           340.0
# ...             ...             ...             ...             ...
# 2352   HopSkipDrive     Los Angeles  Transportation             8.0
# 2353    Panda Squad     SF Bay Area        Consumer             6.0
# 2354  Tamara Mellon     Los Angeles          Retail            20.0
# 2355       EasyPost  Salt Lake City       Logistics            75.0
# 2356      Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off       date     stage        country  \
# 0                    0.05 2023-03-06  Post-IPO      Australia
# 1                    0.08 2023-03-06  Post-IPO  United States
# 2                     NaN 2023-03-06  Series B        Nigeria
# 3                     NaN 2023-03-06   Unknown          India
# 4                    0.15 2023-03-03   Unknown         Brazil
# ...                   ...        ...       ...            ...
# 2352                 0.10 2020-03-13   Unknown  United States
# 2353                 0.75 2020-03-13      Seed  United States
# 2354                 0.40 2020-03-12  Series C  United States
# 2355                  NaN 2020-03-11  Series A  United States
# 2356                 0.14        NaT  Post-IPO  United States
#
#       funds_raised_millions
# 0                     210.0
# 1                     525.0
# 2                      16.0
# 3                     631.0
# 4                     788.0
# ...                     ...
# 2352                   45.0
# 2353                    1.0
# 2354                   90.0
# 2355                   12.0
# 2356                    NaN
#
# [2356 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# company                    0
# location                   0
# industry                   4
# total_laid_off           739
# percentage_laid_off      784
# date                       1
# stage                      6
# country                    0
# funds_raised_millions    209
# dtype: int64

# %%
df.describe()
# Out:
#        total_laid_off  percentage_laid_off  funds_raised_millions
# count     1617.000000          1572.000000            2147.000000
# mean       237.265925             0.258033             823.135210
# std        769.807209             0.255875            5600.341074
# min          3.000000             0.000000               0.000000
# 25%         36.000000             0.100000              50.000000
# 50%         80.000000             0.170000             156.000000
# 75%        180.000000             0.300000             445.000000
# max      12000.000000             1.000000          121900.000000

# %%
df.corr()
# Out:
# C:\Users\Bapela Kanyane\AppData\Local\Temp\ipykernel_11888\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                        total_laid_off  percentage_laid_off  \
# total_laid_off               1.000000            -0.057533
# percentage_laid_off         -0.057533             1.000000
# funds_raised_millions        0.077194            -0.067607
#
#                        funds_raised_millions
# total_laid_off                      0.077194
# percentage_laid_off                -0.067607
# funds_raised_millions               1.000000

# %%
df
# Out:
#             company        location        industry  total_laid_off  \
# 0         Atlassian          Sydney           Other           500.0
# 1          SiriusXM   New York City           Media           475.0
# 2            Alerzo          Ibadan          Retail           400.0
# 3            UpGrad          Mumbai       Education           120.0
# 4              Loft       Sao Paulo     Real Estate           340.0
# ...             ...             ...             ...             ...
# 2352   HopSkipDrive     Los Angeles  Transportation             8.0
# 2353    Panda Squad     SF Bay Area        Consumer             6.0
# 2354  Tamara Mellon     Los Angeles          Retail            20.0
# 2355       EasyPost  Salt Lake City       Logistics            75.0
# 2356      Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off       date     stage        country  \
# 0                    0.05 2023-03-06  Post-IPO      Australia
# 1                    0.08 2023-03-06  Post-IPO  United States
# 2                     NaN 2023-03-06  Series B        Nigeria
# 3                     NaN 2023-03-06   Unknown          India
# 4                    0.15 2023-03-03   Unknown         Brazil
# ...                   ...        ...       ...            ...
# 2352                 0.10 2020-03-13   Unknown  United States
# 2353                 0.75 2020-03-13      Seed  United States
# 2354                 0.40 2020-03-12  Series C  United States
# 2355                  NaN 2020-03-11  Series A  United States
# 2356                 0.14        NaT  Post-IPO  United States
#
#       funds_raised_millions
# 0                     210.0
# 1                     525.0
# 2                      16.0
# 3                     631.0
# 4                     788.0
# ...                     ...
# 2352                   45.0
# 2353                    1.0
# 2354                   90.0
# 2355                   12.0
# 2356                    NaN
#
# [2356 rows x 9 columns]

# %%
df.dropna(subset=['total_laid_off','percentage_laid_off'], how='all', inplace= True)
df
# Out:
# C:\Users\Bapela Kanyane\AppData\Local\Temp\ipykernel_11888\2597188987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['total_laid_off','percentage_laid_off'], how='all', inplace= True)
#             company        location        industry  total_laid_off  \
# 0         Atlassian          Sydney           Other           500.0
# 1          SiriusXM   New York City           Media           475.0
# 2            Alerzo          Ibadan          Retail           400.0
# 3            UpGrad          Mumbai       Education           120.0
# 4              Loft       Sao Paulo     Real Estate           340.0
# ...             ...             ...             ...             ...
# 2352   HopSkipDrive     Los Angeles  Transportation             8.0
# 2353    Panda Squad     SF Bay Area        Consumer             6.0
# 2354  Tamara Mellon     Los Angeles          Retail            20.0
# 2355       EasyPost  Salt Lake City       Logistics            75.0
# 2356      Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off       date     stage        country  \
# 0                    0.05 2023-03-06  Post-IPO      Australia
# 1                    0.08 2023-03-06  Post-IPO  United States
# 2                     NaN 2023-03-06  Series B        Nigeria
# 3                     NaN 2023-03-06   Unknown          India
# 4                    0.15 2023-03-03   Unknown         Brazil
# ...                   ...        ...       ...            ...
# 2352                 0.10 2020-03-13   Unknown  United States
# 2353                 0.75 2020-03-13      Seed  United States
# 2354                 0.40 2020-03-12  Series C  United States
# 2355                  NaN 2020-03-11  Series A  United States
# 2356                 0.14        NaT  Post-IPO  United States
#
#       funds_raised_millions
# 0                     210.0
# 1                     525.0
# 2                      16.0
# 3                     631.0
# 4                     788.0
# ...                     ...
# 2352                   45.0
# 2353                    1.0
# 2354                   90.0
# 2355                   12.0
# 2356                    NaN
#
# [1995 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# company                    0
# location                   0
# industry                   4
# total_laid_off           378
# percentage_laid_off      423
# date                       1
# stage                      5
# country                    0
# funds_raised_millions    165
# dtype: int64

# %%
df.fillna({'industry':df['industry'].mode()[0],
         'stage':df['stage'].mode()[0],
          'total_laid_off':df['total_laid_off'].mean(),
          'percentage_laid_off':df['percentage_laid_off'].mean(),
          'funds_raised_millions':df['funds_raised_millions'].mean()}, inplace= True)
# Out:
# C:\Users\Bapela Kanyane\AppData\Local\Temp\ipykernel_11888\945830305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna({'industry':df['industry'].mode()[0],

# %%
df.isnull().sum()
# Out:
# company                  0
# location                 0
# industry                 0
# total_laid_off           0
# percentage_laid_off      0
# date                     1
# stage                    0
# country                  0
# funds_raised_millions    0
# dtype: int64

# %%
df.fillna(method = 'ffill', inplace = True)
# Out:
# C:\Users\Bapela Kanyane\AppData\Local\Temp\ipykernel_11888\3916497771.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(method = 'ffill', inplace = True)

# %%
df.isnull().sum()
# Out:
# company                  0
# location                 0
# industry                 0
# total_laid_off           0
# percentage_laid_off      0
# date                     0
# stage                    0
# country                  0
# funds_raised_millions    0
# dtype: int64

# %%
df.to_excel("C:\\Users\\Bapela Kanyane\\Documents\LayoffsCleaned.xlsx")
